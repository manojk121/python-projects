# %%
while True: 
    username = input("input your user name : ") 
    if username == "manoj123": 
        password = input("enter your password : ")
        if password == "manoj@317": 
            print("login successful") 
            break
        else:
            print("try again")
    else:
        print("try again")

books = {"maths": 30, "english": 20, "hindi": 10, "science": 5}
bb = {}
total_book = 0

print("""press 1 to borrow book
press 2 to return book
press 3 to add book
press 4 to see stocks of books""")
while True:
    choice = int(input("inter your choice between 1 to 4 : "))

    if choice == 1:
        name = input("enter your name : ")
        n_books = []
        while True:
            book = input("inter book name : ")
            books[book]-= 1
            n_books.append(book)
            bb[name] = n_books
            repeat = input("add more books : ")
            if repeat == "no":
                print(books)
                print(bb)
                break

    elif choice == 2:
        name = input("enter your name : ")
        num_books = []
        while True:
            book = input("enter book name : ")
            books[book]+=1
            num_books.append(book)
            bb[name] = num_books
            repeat = input("return more book : ")
            if repeat == "no":
                print(books)
                print(bb)
                break
            
    elif choice == 3:
        name = input("enter your name : ")
        while True:
             book = input("enter book name : ")
             books[book]+= 1
             repeat = input("add more books : ")
             if repeat == "no":
                 print(books)
                 print(bb)
                 break

    elif choice == 4:
        name = input("enter your name : ")
        for i in books.items():
            print(i)
        print(books)
        print(bb)
    else:
        repeat = input("do you want to repeat again : ")
        if repeat == "no":
            break
